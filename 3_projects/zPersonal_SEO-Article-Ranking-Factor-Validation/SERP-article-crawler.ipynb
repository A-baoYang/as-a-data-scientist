# %%
import json
import requests
import pandas as pd
from urllib.parse import urlencode, quote_plus
# https://stackoverflow.com/questions/40557606/how-to-url-encode-in-python-3
from bs4 import BeautifulSoup
from tqdm import tqdm

# %% [markdown]
# ### SERP Crawler
# #### rule by top domains
# (6,7,8,9,10名都是公司網站首頁，應該不能跟文章優化放在一起比較?)
#
# - da-vinci.com.tw
#     - class: model05
# - inboundmarketing.com.tw
#     - class: elementor-widget-theme-post-content
# - yesharris.com
#     - class: td-post-content
# - growthmarketing.tw
#     - class: entry-content
# - ranking.works
#     - class: article_content
# - awoo.com.tw
#     - class: elementor-widget-container
#
#
# [首頁類] 乾脆就是全抓
# - airnet.com.tw
#     - class: elementor-section-wrap
# - seo.tenten.co
#     - class: gdlr-core-page-builder-body
# - seo.whoops.com.tw
#     - class: elementor-section-wrap
# - seookay.com
#     - id: wrapper
# - taipeiads.com
#     - body
# - corners.com.tw
#     - class: site-main
# - pineapple-web.com
#     - class: content
# - leononline.com.tw
#     - class: elementor-section-wrap
# - sharktech.tw
#     - class:
# - seo-seo.com.tw
# - iwangoweb.com
# - appleseo.com.tw
# - iware.com.tw
# - ibest.tw
# - teng.com.tw
# - leftmoon.co
#
# 有的是首頁、有的是服務介紹頁、有的是引導式文章(引導預約諮詢)
# 同個網域下，這三種網頁架構也不同，很難全部人工標好要抓的 css rule
#
# 網頁上所有文字都抓的合理說法：
#
# 對搜尋引擎來說，也是因為他認為會搜尋「seo公司」的 user 想看這樣的首頁內容，才會出現這些網頁；
# 就算會有跟seo服務、知識無關的雜訊字詞 (ex: 關於我們、聯絡我們)，如果所有網站都抓了，他們也會相對變得不重要
#
#
# #### BeautifulSoup selector
# https://www.itread01.com/content/1536692545.html

# %%
base_url = 'https://www.google.com/search?'
search_keyword = 'seo 公司'
num = 50
headers = {
    'content-type': 'text/html; charset=UTF-8',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/76.0.3809.132 Safari/537.36'
}

params = {'q': search_keyword, 'num': num}
target_url = base_url + urlencode(params, quote_via=quote_plus)
print(target_url)
# Out:
# https://www.google.com/search?q=seo+%E5%85%AC%E5%8F%B8&num=50

# %%
collect = list()

html = requests.get(target_url, headers=headers, timeout=15).content
soup = BeautifulSoup(html, 'html.parser')
# print(soup.prettify())
for block in soup.find_all('div', class_='g'):
    title = block.h3.text
    desc = block.find('span', class_='st').text
    link = block.find('a').attrs['href']
    collect.append([title, desc, link])

df = pd.DataFrame(collect, columns=['title', 'desc', 'link'])
print(df.shape)
df.head()
# Out:
# (50, 3)
#                                    title  \
# 0  SEO收費行情？該怎麼選擇SEO公司?-SEO優化-部落格-達文西 ...
# 1      【SEO關鍵字公司】SEO公司怎麼選？看這篇推薦最適合你的 ...
# 2          行銷人必讀，找SEO顧問前你該知道的事| Harris先生
# 3     SEO 公司怎麼選才有效？搞懂SEO 公司服務類型、收費以及 ...
# 4   【SEO觀念7】SEO 公司挑選指南：認識SEO 顧問與優化服務 ...
#
#                                                 desc  \
# 0  2020年3月17日 - 大家都在討論SEO關鍵字排名，市場報價非常紊亂，比網頁設計更沒有報...
# 1  一個合格的SEO公司能為你服務的，而不是只是單純的排名與成效收費，傳統類型的SEO 公司更重...
# 2  以SEO顧問公司來說，即便顧問公司的顧問有行銷專業、網站分析專業、廣告投放的專業，你跑去問他...
# 3  2020年7月28日 - 想做SEO 的品牌，無非是想要獲得更多「自然搜尋流量」，讓更多潛在...
# 4  2019年8月18日 - 不同階段的企業可以藉由SEO 達到什麼樣的效益、服務有哪些形式以及...
#
#                                                 link
# 0       https://www.da-vinci.com.tw/tw/blog/seo-cost
# 1  https://inboundmarketing.com.tw/seo/seo%E5%85%...
# 2       https://www.yesharris.com/before-seo-agency/
# 3  https://growthmarketing.tw/seo%E5%84%AA%E5%8C%...
# 4  https://ranking.works/SEO%E6%95%99%E5%AD%B8/SE...

# %%
df.to_csv('SERP_{}_num_{}.csv'.format(search_keyword, num), index=False)

# %%
# df = pd.read_csv('SERP_{}_num_{}.csv'.format(search_keyword, num))
[x for x in df.link.values if x.count('/') > 3]
# Out:
# ['https://www.da-vinci.com.tw/tw/blog/seo-cost',
#  'https://inboundmarketing.com.tw/seo/seo%E5%85%AC%E5%8F%B8%E6%8E%A8%E8%96%A6.html',
#  'https://www.yesharris.com/before-seo-agency/',
#  'https://growthmarketing.tw/seo%E5%84%AA%E5%8C%96%E5%85%AC%E5%8F%B8/',
#  'https://ranking.works/SEO%E6%95%99%E5%AD%B8/SEO%E5%85%AC%E5%8F%B8',
#  'https://www.airnet.com.tw/seo%E5%85%AC%E5%8F%B8/',
#  'https://www.awoo.com.tw/blog/seo-company/',
#  'https://www.pineapple-web.com/tw/seo-agency/',
#  'https://www.asiapacdigital.com/zh-cht/SEO',
#  'https://www.newscan.com.tw/all-seo/seo-guide.htm',
#  'https://medium.com/@u78150722/seo%E5%85%AC%E5%8F%B8%E9%80%99%E5%80%91%E5%A4%9A%E5%93%AA%E5%80%8B%E6%89%8D%E6%98%AF%E5%A5%BD%E7%9A%84-3%E5%80%8B%E9%81%B8%E6%93%87%E9%87%8D%E9%BB%9E%E5%91%8A%E8%A8%B4%E4%BD%A0-ea1cbe5da2ea',
#  'https://www.104.com.tw/job/6wi1a',
#  'https://meethub.bnext.com.tw/%E3%80%902019%E6%9C%80%E6%96%B0%E3%80%91seo%E8%A6%81%E6%80%8E%E9%BA%BC%E5%81%9A%EF%BC%9Fseo%E6%93%8D%E4%BD%9C%E6%95%88%E7%9B%8A%E8%88%87seo%E5%85%AC%E5%8F%B8%E5%BF%85%E7%9F%A5/',
#  'https://www.ringoli.net/seo-%E5%85%AC%E5%8F%B8%E6%9C%83%E5%90%A6%E5%87%BA%E9%99%B0%E6%8B%9B%E5%91%A2/',
#  'https://www.hububble.co/blog/seo-expert/',
#  'https://www.creartive.com.tw/articles/how-to-choose-seo-company.shtml',
#  'http://aun-taiwan.com.tw/lp/seo/',
#  'https://www.polaris.net.tw/tw/service/seo.html',
#  'https://www.ready-market.com/zh-TW/faq/SEO/Seo-Cheating.html',
#  'http://www.ieo.com.tw/category/seo%E5%85%AC%E5%8F%B8/',
#  'https://www.nss.com.tw/2020%E5%B9%B47%E6%9C%88%E6%9C%80%E6%96%B0%E5%8F%B0%E7%81%A3%E5%90%84%E5%AE%B6seo%E5%85%AC%E5%8F%B8%E6%8E%92%E5%90%8D%E5%84%AA%E5%8C%96%E8%B2%BB%E7%94%A8%E6%94%B6%E8%B2%BB%E4%B8%80%E8%A6%BD%E8%A1%A8/',
#  'https://appseoweb.com/Internet_Marketing/%E7%B6%B2%E7%AB%99%E8%A8%AD%E8%A8%88%E5%A5%BD%E4%BA%86%EF%BC%8C%E7%82%BA%E4%BB%80%E9%BA%BC%E8%A6%81%E5%81%9ASEO%E6%90%9C%E5%B0%8B%E6%8E%92%E5%90%8D/58',
#  'https://www.eg-creative.com/seo/',
#  'https://www.eg-creative.com/category/seo/',
#  'https://support.google.com/webmasters/answer/35291?hl=zh-Hant',
#  'https://www.unicornws.com/%E3%80%8A%E4%B8%80%E9%9A%BB%E8%B3%BD%E9%B4%BF%E6%8F%AD%E7%99%BC-seo-%E5%85%AC%E5%8F%B8%E4%B8%8D%E9%A1%98%E5%91%8A%E8%A8%B4%E4%BD%A0%E7%9A%84%E4%BA%8B%E3%80%8B/',
#  'https://www.ibest.com.tw/news-detail/seo-considerations/',
#  'https://www.firstpage.hk/zh/seo/',
#  'https://www.yourator.co/companies/Aloha/jobs/4996?locale=zh-TW',
#  'https://www.ykqk.com.tw/other/keyword.php',
#  'https://www.hdcourse.com/seo/seo-service-price/']

# %%
collect = list()

for link in tqdm(df.link.values):
# link = df.link.values[0]
    html = requests.get(link, headers=headers, timeout=15).content
    soup = BeautifulSoup(html, 'html.parser')
    try:
        article_desc = soup.find_all(attrs={'name': 'description'})[0].attrs['content']
    except:
        article_desc = ''

    try:
        article_keywords = soup.find_all(attrs={'name': 'keyword'})[0].attrs['content']
    except:
        article_keywords = ''
    
    # https://stackoverflow.com/questions/22799990/beatifulsoup4-get-text-still-has-javascript
    # kill all script and style elements
    for script in soup(["script", "style"]):
        script.decompose()    # rip it out
    # get text
    text = soup.body.get_text()
    # break into lines and remove leading and trailing space on each
    lines = (line.strip() for line in text.splitlines())
    # break multi-headlines into a line each
    chunks = (phrase.strip() for line in lines for phrase in line.split("  "))
    # drop blank lines
    article_content = ' '.join(chunk for chunk in chunks if chunk)
    
#     line_collect = list()
#     for line in soup.body.stripped_strings:
#         line_collect.append(line)
#     article_content = ' '.join(line_collect)

    try:
        article_published_time = soup.find_all(attrs={'property': 'article:published_time'})[0].attrs['content']
    except:
        article_published_time = ''

    try:
        article_modified_time = soup.find_all(attrs={'property': 'article:modified_time'})[0].attrs['content']
    except:
        article_modified_time = ''

    try:
        article_schema = soup.find_all(attrs={'type': 'application/ld+json'})[0].text
    except:
        article_schema = ''
    else:
        if (article_published_time == '') and ('datePublished' in article_schema):
            try:
                article_published_time = json.loads(article_schema)['@graph'][1]['datePublished']
            except:
                try:
                    article_published_time = json.loads(article_schema)[0]['datePublished']
                except:
                    try:
                        article_published_time = json.loads(article_schema)['@graph'][3]['datePublished']
                    except:
                        try:
                            article_published_time = json.loads(article_schema)['@graph'][2]['datePublished']
                        except:
                            try:
                                article_published_time = json.loads(article_schema)['datePublished']
                            except:
                                article_published_time = json.loads(article_schema)['@graph'][0]['datePublished']
                                
                            
#                     print(json.loads(article_schema))

        if (article_modified_time == '') and ('dateModified' in article_schema):
            try:
                article_modified_time = json.loads(article_schema)['@graph'][1]['dateModified']
            except:
                try:
                    article_modified_time = json.loads(article_schema)[0]['dateModified']
                except:
                    try:
                        article_modified_time = json.loads(article_schema)['@graph'][3]['dateModified']
                    except:
                        try:
                            article_modified_time = json.loads(article_schema)['@graph'][2]['dateModified']
                        except:
                            try:
                                article_modified_time = json.loads(article_schema)['dateModified']
                            except:
                                article_modified_time = json.loads(article_schema)['@graph'][0]['dateModified']
                                

        if (article_keywords == '') and ('keywords' in article_schema):
            try:
                article_keywords = json.loads(article_schema)[0]['keywords']
            except:
                try:
                    article_keywords = json.loads(article_schema)['@graph'][5]['keywords']
                except:
                    article_keywords = json.loads(article_schema)['keywords']                    
#                 print(json.loads(article_schema))
    
    collect.append([link, article_desc, article_keywords, article_content, article_published_time, article_modified_time, article_schema])
# Out:
#   0%|                                                                                                                                                                                                                | 0/50 [00:00<?, ?it/s]
#
#
#
#
#
#   2%|████                                                                                                                                                                                                    | 1/50 [00:00<00:08,  5.49it/s]
#
#
#
#
#
#   4%|████████                                                                                                                                                                                                | 2/50 [00:00<00:09,  4.87it/s]
#
#
#
#
#
#   6%|████████████                                                                                                                                                                                            | 3/50 [00:00<00:08,  5.24it/s]
#
#
#
#
#
#   8%|████████████████                                                                                                                                                                                        | 4/50 [00:01<00:20,  2.23it/s]
#
#
#
#
#
#  10%|████████████████████                                                                                                                                                                                    | 5/50 [00:02<00:25,  1.75it/s]
#
#
#
#
#
#  12%|████████████████████████                                                                                                                                                                                | 6/50 [00:02<00:21,  2.03it/s]
#
#
#
#
#
#  14%|████████████████████████████                                                                                                                                                                            | 7/50 [00:03<00:22,  1.87it/s]
#
#
#
#
#
#  16%|████████████████████████████████                                                                                                                                                                        | 8/50 [00:04<00:30,  1.37it/s]
#
#
#
#
#
#  18%|████████████████████████████████████                                                                                                                                                                    | 9/50 [00:04<00:22,  1.83it/s]
#
#
#
#
#
#  20%|███████████████████████████████████████▊                                                                                                                                                               | 10/50 [00:06<00:35,  1.14it/s]
#
#
#
#
#
#  22%|███████████████████████████████████████████▊                                                                                                                                                           | 11/50 [00:06<00:25,  1.51it/s]
#
#
#
#
#
#  24%|███████████████████████████████████████████████▊                                                                                                                                                       | 12/50 [00:06<00:19,  1.98it/s]
#
#
#
#
#
#  26%|███████████████████████████████████████████████████▋                                                                                                                                                   | 13/50 [00:06<00:16,  2.27it/s]
#
#
#
#
#
#  28%|███████████████████████████████████████████████████████▋                                                                                                                                               | 14/50 [00:08<00:32,  1.12it/s]
#
#
#
#
#
#  30%|███████████████████████████████████████████████████████████▋                                                                                                                                           | 15/50 [00:09<00:26,  1.33it/s]
#
#
#
#
#
#  32%|███████████████████████████████████████████████████████████████▋                                                                                                                                       | 16/50 [00:09<00:22,  1.52it/s]
#
#
#
#
#
#  34%|███████████████████████████████████████████████████████████████████▋                                                                                                                                   | 17/50 [00:10<00:18,  1.81it/s]
#
#
#
#
#
#  36%|███████████████████████████████████████████████████████████████████████▋                                                                                                                               | 18/50 [00:11<00:29,  1.07it/s]
#
#
#
#
#
#  38%|███████████████████████████████████████████████████████████████████████████▌                                                                                                                           | 19/50 [00:12<00:24,  1.25it/s]
#
#
#
#
#
#  40%|███████████████████████████████████████████████████████████████████████████████▌                                                                                                                       | 20/50 [00:12<00:17,  1.67it/s]
#
#
#
#
#
#  42%|███████████████████████████████████████████████████████████████████████████████████▌                                                                                                                   | 21/50 [00:12<00:15,  1.88it/s]
#
#
#
#
#
#  44%|███████████████████████████████████████████████████████████████████████████████████████▌                                                                                                               | 22/50 [00:13<00:17,  1.62it/s]
#
#
#
#
#
#  46%|███████████████████████████████████████████████████████████████████████████████████████████▌                                                                                                           | 23/50 [00:13<00:13,  1.97it/s]
#
#
#
#
#
#  48%|███████████████████████████████████████████████████████████████████████████████████████████████▌                                                                                                       | 24/50 [00:14<00:11,  2.36it/s]
#
#
#
#
#
#  50%|███████████████████████████████████████████████████████████████████████████████████████████████████▌                                                                                                   | 25/50 [00:15<00:13,  1.80it/s]
#
#
#
#
#
#  52%|███████████████████████████████████████████████████████████████████████████████████████████████████████▍                                                                                               | 26/50 [00:17<00:27,  1.14s/it]
#
#
#
#
#
#  54%|███████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                                                                           | 27/50 [00:17<00:20,  1.12it/s]
#
#
#
#
#
#  56%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                                                                       | 28/50 [00:18<00:14,  1.50it/s]
#
#
#
#
#
#  58%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                                                                   | 29/50 [00:18<00:13,  1.56it/s]
#
#
#
#
#
#  60%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                                                               | 30/50 [00:18<00:09,  2.04it/s]
#
#
#
#
#
#  62%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                                                                           | 31/50 [00:22<00:26,  1.40s/it]
#
#
#
#
#
#  64%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                                                                       | 32/50 [00:22<00:18,  1.03s/it]
#
#
#
#
#
#  66%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                                                                   | 33/50 [00:22<00:14,  1.19it/s]
#
#
#
#
#
#  68%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                                                               | 34/50 [00:24<00:18,  1.16s/it]
#
#
#
#
#
#  70%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                                                           | 35/50 [00:24<00:13,  1.15it/s]
#
#
#
#
#
#  72%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                                                       | 36/50 [00:25<00:09,  1.44it/s]
#
#
#
#
#
#  74%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                                                   | 37/50 [00:25<00:09,  1.43it/s]
#
#
#
#
#
#  76%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                               | 38/50 [00:26<00:07,  1.56it/s]
#
#
#
#
#
#  78%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                           | 39/50 [00:26<00:06,  1.78it/s]
#
#
#
#
#
#  80%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                       | 40/50 [00:29<00:10,  1.05s/it]
#
#
#
#
#
#  82%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                                   | 41/50 [00:29<00:07,  1.22it/s]
#
#
#
#
#
#  84%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                               | 42/50 [00:29<00:05,  1.53it/s]
#
#
#
#
#
#  86%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                           | 43/50 [00:29<00:03,  1.91it/s]
#
#
#
#
#
#  88%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                        | 44/50 [00:30<00:02,  2.07it/s]
#
#
#
#
#
#  90%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                    | 45/50 [00:31<00:03,  1.59it/s]
#
#
#
#
#
#  92%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                | 46/50 [00:31<00:01,  2.05it/s]
#
#
#
#
#
#  94%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████            | 47/50 [00:31<00:01,  2.68it/s]
#
#
#
#
#
#  96%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████        | 48/50 [00:31<00:00,  3.05it/s]
#
#
#
#
#
#  98%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████    | 49/50 [00:32<00:00,  2.36it/s]
#
#
#
#
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 50/50 [00:32<00:00,  2.84it/s]

# %%
# json.loads(article_schema)['@graph'][0]#['datePublished']
# Out:
# Skip to content
# Menu
# 主頁
# 數碼營銷課程
# Blog
# Jobs
# 找工作
# 發布工作
# 關於我們
# 會員註冊
# FREE (7 個課程)
# 月費計劃 HKD$97 (50 個課程)
# 永久計劃 HKD$2,910 (50 個課程)
# 登入
# 點揀 SEO 公司? 究竟香港SEO公司 有幾多間？知唔知SEO 報價最平幾錢？
# by ivan so
# 當你去香港 SEO公司拿取 SEO 報價的時候，會得到很多個不同的服務版本及SEO價錢，SEO最平價格我看過有 $3,000，相對昂貴的有 $30,000，收費相差可以有 10 倍之大，如果你需要一個平均數，SEO 費用平均需要 $8,000 左右，而且這個 SEO 費用是每個月的。
# 有些人會用 Facebook ads 及 Google ads (SEM) 作出比較，從而衡量 SEO 的價值。
# 香港 SEO 公司有多少間？
# 香港 SEO 公司有很多間，當你於 Google 輸入SEO優化公司或SEO服務的時候，我估沒有 100 間也有 70 間公司提供搜尋引擎最佳化服務，SEO Hong Kong 公司及 digital marketing 公司有 HKGSEO、Ringoli 及 Hellotoby 平台的SEO服務商。
# 一些是網上推廣公司的 SEO 優化服務只是其中一個服務，你要了解一下他們搜尋引擎優化 search engine optimization 服務的專業性。
# 坊間 SEO 報價單
# 搜尋引擎關鍵字困難程度SEO 網站優化費用 / 月Google HK高$1,000 / 關鍵字Google HK中$500 / 關鍵字Google HK低$200 / 關鍵字
# Table Of Contents香港 SEO 公司有多少間？SEO服務的 8 個項目5 大 SEO 公司推薦的方法您需要 SEO 的幫助嗎？
# SEO服務的 8 個項目
# (1) 網站審計
# SEO 公司會用一些搜尋引擎最佳化工具去審計你網站的及提供建議， SEO 工具包括 ahrefs、moz、semrush 及 woorank。
# Moz bar: https://moz.com/products/pro/seo-toolbar (free)
# (2) 關鍵字查詢
# SEO 服務包括 Google 關鍵字查詢，他們會進行一些關鍵字建議，有一些是比較困難獲得的，有一些是長尾關鍵字。
# (3) 內容撰寫
# 有些客戶因為業務繁忙，會使用他們其中一個搜尋器優化 SEO服務 就是內容撰寫，因為他們已經幫你做了關鍵字查詢。
# 然後再做內容比較容易，他們撰寫的基礎是根據那些關鍵字去完成。
# (4) SEO 設定
# 如果你的網站連一些基本的 SEO 設定也沒有，他們會幫你的網站提供這個搜尋引擎最佳化服務，連接 console 為其中之一，令你了解網站 SEO 的層面比較廣闊。
# (5) 技術性 SEO 搜尋引擎優化：結構化數據
# 有一些 SEO 公司會有技術團隊，所以可以作出一些技術性搜尋引擎最佳化的建議，建議你更改網站從而符合結構化數據及可以提交 sitemap xml 到 console 之內。
# (6) 網站優化建議（不包括更改程式）
# 我接觸過很多的 SEO 公司，他們的服務其實不包括網站更改程式，因為每個客戶網站的程式也不一樣，所以他們通常是基於一些 SEO 工具作出搜尋引擎最佳化的建議，而且也會建議你提升網站的速度及改善 meta。
# (7) 反向連結建立
# 使用 SEO 服務其中一個重要環節就是反向連結的建立，因為這個環節是最困難的，有一些香港 SEO 公司自己會有私人博客網絡 (PBN)
# 他們可以自己決定如何放你的連結到他們的網絡之內，不過 Google 有提及過不太建議網站使用私人博客網絡 (PBN)。
# 另一個方法是，他們會代表你的網站去洽談不同的網站，從而建立反向連結，這個過程比較漫長及機會率較低。
# (8) 每周或每兩周的 SEO 報告
# 香港 SEO 公司會每周或每兩周提交搜尋引擎最佳化進度報告給客戶，從而決定未來的時間會着重那一些關鍵字及撰寫那一類的內容，SEO專家 也會提供一些建議去做內部連結。
# 5 大 SEO 公司推薦的方法
# 如果你真的需要進行外包SEO服務的時候，不妨了解以下 5 個選擇服務商的注意事項，做個精明消費者。
# (1) 客戶案例
# 如果 SEO公司有較長的歷史及經驗，應該累積了不少按例，嘗試了解一下有沒有比較類似你的行業。
# 他們是如何操作，需要多少時間可以達到多少個關鍵字排到第一頁的效果。
# (2) 如何幫助你進行 Google 關鍵字查詢
# 了解SEO服務商如何進行 Google 關鍵字查詢是有好處的，你會可以理解到他們是直接於 Google 進行關鍵字查詢或第三方的工具，因為如果使用第三方的工具，確實是有參考的價值，不過絕對沒有比直接於 Google 搜尋引擎之內做查詢及分析那麼準確。
# Google 關鍵字查詢例子
# (3) 如何應對服務進行之後流量下跌
# 使用 SEO服務之後流量下跌，這是沒有人想看到的結果，但是如果不幸地發生，預先了解一下 SEO公司會如何應對這個狀況，不失為一個預先理解這 SEO公司的經驗及應變的一個好方法。
# (4) 收費是否合理
# SEO公司的收費可以十分浮動，我有看過由 $5,000 至 $30,000 的價格，所以你必須要貨比 3 家。
# 拿了 3 個報價之後，再作出比較及衡量，他們提供的服務是否一致，或是有些 SEO公司提供較多的服務，所以收費較昂貴。
# (5) 如何進行反向連結 backlink
# 反向連結 backlink 一向都是 SEO 操作裹最困難的一環，所以你必須查詢你的 SEO公司，他們是如何進行這個 SEO 反向連結操作。
# 他們是否會使用私人博客網絡 (PBN)，還是會代表你的公司去接觸其他網站進行反向連結。
# 希望這 5 大防伏嚴選 SEO公司的方法可以給你一點啟示，下次當你需要外包到 SEO公司的時候，你知道如何基本地衡量他們的SEO專家實力，令你的金錢能夠花費到一個合適的地方。
# 您需要 SEO 的幫助嗎？
# 基本地衡量SEO專家的實力，您可以查看他們是否可以對自己的公司進行 SEO 排名。
# 以下數據截至 2020 年 6 月 28 日，是我的網站排名。
# 桌面排名
# 手機排名
# 如果您需要我的 SEO 協助或公司培訓，請給我發電子郵件。
# FAQ
# 香港 SEO公司有多少間？粗略估計，沒有 100 間也有 70 間 香港 SEO公司 提供搜尋引擎最佳化服務。SEO 服務價格是多少？比較平的我看過有 $5,000 ，相對昂貴的有 $30,000，這個 SEO 報價 是每個月計算的。SEO服務包括什麼項目？簡單來說，SEO服務包括大概 8 個項目，由網站審計、關鍵字查詢、內容撰寫及網站優化建議。
# Categories Featured, SEO Tags Google 關鍵字查詢, SEO 價錢, SEO 工具, SEO 服務, 反向連結, 技術性 SEO, 搜尋引擎優化, 搜尋引擎優化服務, 搜尋引擎最佳化, 搜尋引擎最佳化服務 Leave a comment
# Post navigation
# WordPress Hosting 網站寄存公司比較 (Bluehost, Siteground, Mediatemple, Wpengine, Kinsta)誰是 SEO專家？SEO 專家正在使用的 3 個方法，學習理解 Search engine 很重要
# Leave a Comment Cancel replyCommentName
# Email
# Website
# Save my name, email, and website in this browser for the next time I comment.
# Digital tips 免費登記 newsletter
# Recent Posts
# 垃圾文章 SEO 排名測試
# Facebook 廣告測試：$2,000 多元可以接觸到 20 萬人 (Reach and frequency模式)
# Google 手機優先 indexing 延遲至 2021 年 3 月
# 以喵喵為題，測試重複出現 1,750 次的關鍵字對 SEO 有何影響
# 海量的負評會傷害 SEO 排名?
# Recent Commentsivan so on 第2天rickylee_hk@hotmail.com on 第2天ivan so on 港台星馬 50 個 WordPress 資深用家分享 pluginsShock Media Studio on 港台星馬 50 個 WordPress 資深用家分享 pluginsivan so on Yoast SEO 及 Rank Math SEO，那一個適合我？
# 用戶推薦
# Ivan係一個好有心亦好有實力既人。
# 令我呢個新手都可以輕鬆掌握新技能。
# Joe Yau
# 非常好的課程，內容很全面，道理也講得很清晰，適合各自程度的人。
# Colleen Wong
# 我記得有一次，網站受到隨機攻機。
# Ivan 很專業地告訴了我如何做好保障。
# 非常推薦
# Day Chow
# SEO專家，擁有高超技術，超強執行力，友善及親切的笑容。加上高大的身形，磁性的聲線，簡直係Marketing界師奶殺手。😀
# 如要找SEO專家，我十分推薦Ivan給所有人。
# *P.S. 不要被他迷到*❤️
# Eric Kwok Hin
# 其實他的真名是ivan seo，他seo技術及知識是不容置疑了，但最重要是感染了大家一起學好seo!
# Lucien Li
# Ivan 鼓勵了我多作分享，他個人幽默風趣、又勤力好學。SEO方面很強，人生閱歷又豐富，是個良師益友。
# Felix Fan
# 他除了深研各種類的 SEO 知識和技術，我雖然不是他的學生，但純粹觀賞免費的 SEO 教學影片，已經獲益非淺，比較欣賞 Ivan 喜歡嚐試新鮮事物的探究精神，成功往往是由無數微小的因素組成，觀察與嚐試往往是成功的關鍵。
# Mack Chan
# 見到ivan so既課程真係好好彩, 終於知道點做SEO
# 好實用, 做網站既一定要學呀.
# West Yu Rex
# 課程實用,內容精簡,活躍更新
# Tung Lam
# Ivan的經驗和見解令我對網站設置的思維徹底地激活，感謝Ivan老師無私分享👍
# Evy Chan
# 溝通有熱誠，訊息更新快
# Ken L.H. LEE
# 真人靚過上鏡，SEO 教學靚過真人
# Jazz Wai
# 星級SEO導師。
# Rudi Leung
# 一位經驗豐富的SEO和WordPress專家。如果您想獲取有關SEO和WordPress的最新信息，請關注他😊
# Adam Yong
# Ivan提供了有用的課程和談話，以幫助我們改善網站的SEO。謝謝！
# Peter Ho
# Previous
# Next
# 2019 年成立，HDcourse 課程涵蓋內容包括 SEO、WordPress、電郵營銷及數碼營銷的一些認識。這是一個網上學習的課程，支援短片教學、適合於手機上學習及工作繁忙的人仕，可以令你持續在任何地方進行學習。
# Connect with us
# Facebook-f
# Youtube
# Linkedin
# Twitter
# Spotify
# Meetup
# Link
# Page
# 數碼營銷課程
# SEO 課程
# WordPress 課程
# 網上商店課程
# 關於我們
# 隱私權條款
# Company
# HDcourse Limited地址：香港九龍荔枝角長沙灣道833號長沙灣廣場1座11樓1101室電話：2781 3706電子郵件：ivan@hdcourse.com
# HDcourse © Copyright 2019 - 2020. All rights reserved.
# Made with ❤ with WordPress​
# 主頁
# 數碼營銷課程
# Blog
# Jobs
# 找工作
# 發布工作
# 關於我們
# 會員註冊
# FREE (7 個課程)
# 月費計劃 HKD$97 (50 個課程)
# 永久計劃 HKD$2,910 (50 個課程)
# 登入
# Close

# %%
df = pd.DataFrame(collect, columns=['link', 'article_desc', 'article_keywords', 'article_content', 'article_published_time', 'article_modified_time', 'article_schema'])
print(df.shape)
df.head()
# Out:
# (50, 7)
#                                                 link  \
# 0       https://www.da-vinci.com.tw/tw/blog/seo-cost
# 1  https://inboundmarketing.com.tw/seo/seo%E5%85%...
# 2       https://www.yesharris.com/before-seo-agency/
# 3  https://growthmarketing.tw/seo%E5%84%AA%E5%8C%...
# 4  https://ranking.works/SEO%E6%95%99%E5%AD%B8/SE...
#
#                                         article_desc article_keywords  \
# 0  大家都在討論SEO關鍵字排名，市場報價非常紊亂，比網頁設計更沒有報價依據，加上很多人不懂SE...
# 1  一個合格的SEO公司能為你服務的，而不是只是單純的排名與成效收費，傳統類型的SEO 公司更重...
# 2  即便你找台灣真正懂SEO的人、甚至是台灣最頂尖的專家來輔導你做 SEO，你的 SEO也不一定...
# 3
# 4  不同階段的企業可以藉由 SEO 達到什麼樣的效益、服務有哪些形式以及如何選擇適合的 SEO ...
#
#                                      article_content  \
# 0  搜尋 搜尋 f TW TW CN 首頁 關於我們 公司介紹 專業團隊 服務項目 網頁設計 網...
# 1  集客數據行銷 內容行銷搭配搜尋優化，讓客戶更懂你 數位行銷顧問服務 數位行銷顧問 電商行銷顧...
# 2  關於Harris 文章分類 SEO教學 SEO 基礎教學 SEO 進階觀念 Search C...
# 3  首頁 關於零一 服務介紹 成長顧問諮詢 內容行銷案例 成長行銷知識庫 選單 首頁 關於零一 ...
# 4  服務項目 SEO軟體 SEO教學部落格 關於我們 聯絡我們 註冊/登入 服務項目 SEO軟體...
#
#       article_published_time      article_modified_time article_schema
# 0
# 1  2018-01-14T00:52:34+00:00  2020-04-17T04:05:50+00:00
# 2                 2018-10-08                 2020-08-27
# 3  2020-07-28T22:51:23+00:00  2020-09-07T15:38:48+00:00
# 4

# %%
df.to_csv('{}_{}_articles_features.csv'.format(search_keyword, num), index=False)
