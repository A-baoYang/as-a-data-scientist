# %%
import gc
import sys
sys.path.append('../')
import json
import pandas as pd
pd.set_option('display.max_columns', None)
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
# import seaborn as sns
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
from tqdm import tqdm
from collections import defaultdict

from custom_functions import (
    gen_dayHrMin,
    gen_timeblock
)

# %matplotlib inline

# %% [markdown]
# ### User States 定義
# > action_type: 0 is for click, 1 is for add-to-cart, 2 is for purchase and 3 is for add-to-favourite
#
# ##### 前一版
# > User states 分為兩類，瀏覽類和購買及其意圖類
# > 1. 瀏覽類：離站或有瀏覽，瀏覽中又細分8類(依據瀏覽不重複品類數、品牌數)
# > 2. 購買及其意圖類：無、加入購物車、加入願望清單、購買
#
# > ### 結論：
# > ### **根據 silhouette function 最佳分群為 2 群，能夠解釋的豐富度不夠，看起來只分出進站頻率高低兩群人而已**
#
# ---
#
# #### 測試不同 user state 分法增加分群豐富程度
# ##### V3.1：把購買或加入待購(願望清單/購物車)的意圖動作，和瀏覽(點擊)一併定義 state（９）
# > *加入購物車事件因為數量較少，將其跟購物車事件歸成同一件*
#
# > 1. **少類別瀏覽且當天購買**：只瀏覽2個以內類別、接著在同一天下單
# > 2. **少類別瀏覽且當天加入待購**：一個只瀏覽2個以內類別、接著在同一天只加入願望清單或購物車
# > 3. **少類別瀏覽後無進一步動作**：一個只瀏覽2個以內類別、接著無後續動作
# > 4. **多類別瀏覽且當天購買**：一個只瀏覽3個以上類別、接著在同一天下單
# > 5. **多類別瀏覽且當天加入待購**：一個只瀏覽3個以上類別、接著在同一天只加入願望清單或購物車
# > 6. **多類別瀏覽後無進一步動作**：一個只瀏覽3個以上類別、接著無後續動作
# > 7. **當天只有加入待購**
# > 8. **當天促成購買**
# > 9. **未進站**：該日無事件發生
#
# ##### V3.2：不分 多/少 類別瀏覽（６）
#
# > 1. **瀏覽且當天購買**：一個只瀏覽3個以上類別、接著在同一天下單
# > 2. **瀏覽且當天加入待購**：一個只瀏覽3個以上類別、接著在同一天只加入願望清單或購物車
# > 3. **瀏覽後無進一步動作**：一個只瀏覽3個以上類別、接著無後續動作
# > 4. **當天只有加入待購**
# > 5. **當天促成購買**
# > 6. **未進站**：該日無事件發生
#
# ##### V3.3：不分 多/少 類別瀏覽、但加入願望清單和加入購物車分開看（８）
#
# > 1. **瀏覽且當天購買**：一個只瀏覽3個以上類別、接著在同一天下單
# > 2. **瀏覽且當天加入購物車**：一個只瀏覽3個以上類別、接著在同一天只加入購物車
# > 3. **瀏覽且當天加入願望清單**：一個只瀏覽3個以上類別、接著在同一天只加入願望清單
# > 4. **瀏覽後無進一步動作**：一個只瀏覽3個以上類別、接著無後續動作
# > 5. **當天只有加入購物車**
# > 6. **當天只有加入願望清單**
# > 7. **當天促成購買**
# > 8. **未進站**：該日無事件發生

# %%
produce_date = '201117'
version = 'V3.2-crosscategorypurchase-past14days'
pastDays = 14

# %%
df = pd.read_pickle('../TMall_datasets/TMall_for_user_states_define_transformed.pkl')  # moved to "../TMall_datasets"
df.shape
df.head()
# Out:
# (54925330, 17)
#    user_id  item_id  cat_id  merchant_id brand_id  time_stamp label  \
# 0   328862   323294     833         2882     2661         829     -
# 1   328862   844400    1271         2882     2661         829     -
# 2   328862   575153    1271         2882     2661         829     -
# 3   328862   996875    1271         2882     2661         829     -
# 4   328862  1086186    1271         1253     1049         829     -
#
#    age_range  gender  click  add_to_cart  purchase  add_to_favorite  day  \
# 0        6.0     1.0      1            0         0                0   29
# 1        6.0     1.0      1            0         0                0   29
# 2        6.0     1.0      1            0         0                0   29
# 3        6.0     1.0      1            0         0                0   29
# 4        6.0     1.0      1            0         0                0   29
#
#    month  dayOfWeek  day_stamp
# 0      8          4        110
# 1      8          4        110
# 2      8          4        110
# 3      8          4        110
# 4      8          4        110

# %%
### 計算每個 user 在區間內的購買次數
tmp_df = df[(df['time_stamp']!=1111)].groupby(['user_id','cat_id'])['purchase'].sum().reset_index()
tmp_df = tmp_df[tmp_df['purchase']>0].groupby(['user_id'])['cat_id'].nunique().reset_index()
selected_user_1 = tmp_df[(tmp_df['cat_id']>2)].user_id.unique() # 在雙11以外的，在多個品類瀏覽/購買
tmp_df_2 = df[(df['time_stamp']!=1111)].groupby(['user_id'])['click'].sum().reset_index()
selected_user_2 = tmp_df_2[(tmp_df_2['click']>0)].user_id.unique() # 在雙11以外時間造訪一次以上的人


### 篩選 user
selected_user = []
for u in tqdm(selected_user_1):
    if u in selected_user_2:
        selected_user.append(u)


### 抽樣 1000 位用戶
print(len(selected_user))
selected_user = np.random.choice(selected_user, 1000)
print(len(selected_user))


df_target = df[df['user_id'].isin(selected_user)].sort_values('day_stamp')
print(df_target.shape)
df_target.head()
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 198693/198693 [00:43<00:00, 4594.51it/s]
# 198533
# 1000
# (189532, 17)
#           user_id  item_id  cat_id  merchant_id brand_id  time_stamp label  \
# 24019066   152951   214546    1090         4605     7622         511     -
# 16640096   175992   333753     662         4173     5376         511     -
# 42488701   186120  1073970     602         2591     5120         511     -
# 16640097   175992   207096    1467         3578     3091         511     -
# 16640098   175992  1057639    1467         3578     3091         511     -
#
#           age_range  gender  click  add_to_cart  purchase  add_to_favorite  \
# 24019066        4.0     0.0      0            0         1                0
# 16640096        3.0     0.0      0            0         0                1
# 42488701        3.0     0.0      0            0         0                1
# 16640097        3.0     0.0      0            0         0                1
# 16640098        3.0     0.0      0            0         0                1
#
#           day  month  dayOfWeek  day_stamp
# 24019066   11      5          6          0
# 16640096   11      5          6          0
# 42488701   11      5          6          0
# 16640097   11      5          6          0
# 16640098   11      5          6          0

# %%
###只留下購買前__天的紀錄

df_target = df_target.sort_values('time_stamp').reset_index().drop('index', axis=1)
user_list = df_target.user_id.unique()
user = user_list[0]
purchase_timing = df_target[(df_target['user_id']==user) & (df_target['purchase']>0)].time_stamp.values[0]
df_purchase_a_week_ago = df_target[(df_target['user_id']==user)&(df_target['time_stamp']<=purchase_timing)&(df_target['time_stamp']>=purchase_timing-pastDays)]

for uid in tqdm(user_list[1:]):
    purchase_timing = df_target[(df_target['user_id']==uid) & (df_target['purchase']>0)].time_stamp.values[0]
    tmp_df_2 = df_target[(df_target['user_id']==uid)&(df_target['time_stamp']<=purchase_timing)&(df_target['time_stamp']>=purchase_timing-pastDays)]
    df_purchase_a_week_ago = pd.concat([df_purchase_a_week_ago, tmp_df_2])

print(df_purchase_a_week_ago.shape)
df_purchase_a_week_ago.head()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 999/999 [00:04<00:00, 227.86it/s]
# (12505, 17)
#     user_id  item_id  cat_id  merchant_id brand_id  time_stamp label  \
# 0    152951   214546    1090         4605     7622         511     -
# 1      1368  1036854     177          219     1818         511     -
# 7      1368   807111    1349         1457     4279         511     -
# 8      1368  1007438    1349         1457     3650         511     -
# 37     1368   412630    1349         1457     3650         511     -
#
#     age_range  gender  click  add_to_cart  purchase  add_to_favorite  day  \
# 0         4.0     0.0      0            0         1                0   11
# 1         4.0     0.0      0            0         0                1   11
# 7         4.0     0.0      0            0         0                1   11
# 8         4.0     0.0      0            0         0                1   11
# 37        4.0     0.0      0            0         0                1   11
#
#     month  dayOfWeek  day_stamp
# 0       5          6          0
# 1       5          6          0
# 7       5          6          0
# 8       5          6          0
# 37      5          6          0

# %%
accum_by_timestamp = {}

for uid in tqdm(user_list):
    accum_by_timestamp[str(uid)] = {}
    
    tmp_df = df_purchase_a_week_ago[df_purchase_a_week_ago['user_id']==uid].groupby(['time_stamp'])['click','add_to_cart','add_to_favorite','purchase'].sum()
    tmp_df['add_to_favor_or_cart'] = tmp_df['add_to_favorite'] + tmp_df['add_to_cart']
    tmp_df = tmp_df.drop(['add_to_favorite','add_to_cart'], axis=1)
    tmp_df['unique_cat'] = df_purchase_a_week_ago[df_purchase_a_week_ago['user_id']==uid].groupby(['time_stamp'])['cat_id'].nunique()
    tmp_df = tmp_df.reset_index()#.drop('index', axis=1)

    for i in range(tmp_df.time_stamp.max()-pastDays, tmp_df.time_stamp.max()+1):
        if i not in tmp_df.time_stamp.values:
            tmp_df = pd.concat([tmp_df, pd.DataFrame([[i,0,0,0,0]], columns=tmp_df.columns)], ignore_index=True)

    tmp_df = tmp_df.sort_values('time_stamp').reset_index().drop(['index'], axis=1)
    
    for c in tmp_df.columns:
        accum_by_timestamp[str(uid)][c] = tmp_df[c].values.tolist()
        
        
# accum_by_timestamp
with open('TMall_user_counts_{}_{}.json'.format(produce_date, version), 'w') as fp:
    json.dump(accum_by_timestamp, fp)
# Out:
#   0%|                                                                                                                                                                                                              | 0/1000 [00:00<?, ?it/s]C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#   1%|█▏                                                                                                                                                                                                    | 6/1000 [00:00<00:16, 59.84it/s]C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#   1%|██▌                                                                                                                                                                                                  | 13/1000 [00:00<00:16, 61.12it/s]C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#   2%|███▉                                                                                                                                                                                                 | 20/1000 [00:00<00:15, 62.55it/s]C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#   3%|█████▎                                                                                                                                                                                               | 27/1000 [00:00<00:15, 63.51it/s]C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#   3%|██████▋                                                                                                                                                                                              | 34/1000 [00:00<00:15, 63.42it/s]C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#   4%|████████                                                                                                                                                                                             | 41/1000 [00:00<00:15, 63.86it/s]C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#   5%|█████████▍                                                                                                                                                                                           | 48/1000 [00:00<00:15, 63.22it/s]C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#   6%|██████████▊                                                                                                                                                                                          | 55/1000 [00:00<00:14, 63.47it/s]C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#   6%|████████████▏                                                                                                                                                                                        | 62/1000 [00:00<00:14, 64.26it/s]C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#   7%|█████████████▌                                                                                                                                                                                       | 69/1000 [00:01<00:14, 63.58it/s]C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#   8%|██████████████▉                                                                                                                                                                                      | 76/1000 [00:01<00:14, 64.16it/s]C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#   8%|████████████████▎                                                                                                                                                                                    | 83/1000 [00:01<00:14, 64.57it/s]C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#   9%|█████████████████▋                                                                                                                                                                                   | 90/1000 [00:01<00:14, 64.41it/s]C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#  10%|███████████████████                                                                                                                                                                                  | 97/1000 [00:01<00:13, 64.93it/s]C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#  10%|████████████████████▍                                                                                                                                                                               | 104/1000 [00:01<00:13, 64.84it/s]C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#  11%|█████████████████████▊                                                                                                                                                                              | 111/1000 [00:01<00:13, 63.84it/s]C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#  12%|███████████████████████▏                                                                                                                                                                            | 118/1000 [00:01<00:13, 64.35it/s]C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#  12%|████████████████████████▌                                                                                                                                                                           | 125/1000 [00:01<00:13, 63.99it/s]C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#  13%|█████████████████████████▊                                                                                                                                                                          | 132/1000 [00:02<00:13, 63.57it/s]C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#  14%|███████████████████████████▏                                                                                                                                                                        | 139/1000 [00:02<00:13, 62.94it/s]C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#  15%|████████████████████████████▌                                                                                                                                                                       | 146/1000 [00:02<00:13, 62.92it/s]C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#  15%|█████████████████████████████▉                                                                                                                                                                      | 153/1000 [00:02<00:13, 63.43it/s]C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#  16%|███████████████████████████████▎                                                                                                                                                                    | 160/1000 [00:02<00:13, 63.71it/s]C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#  17%|████████████████████████████████▋                                                                                                                                                                   | 167/1000 [00:02<00:12, 64.51it/s]C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#  17%|██████████████████████████████████                                                                                                                                                                  | 174/1000 [00:02<00:13, 62.72it/s]C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#  18%|███████████████████████████████████▍                                                                                                                                                                | 181/1000 [00:02<00:13, 61.53it/s]C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# ...
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#  94%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████           | 944/1000 [00:14<00:00, 64.37it/s]C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#  95%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍         | 951/1000 [00:15<00:00, 63.57it/s]C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#  96%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊        | 958/1000 [00:15<00:00, 63.71it/s]C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#  96%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏      | 965/1000 [00:15<00:00, 63.38it/s]C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#  97%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌     | 972/1000 [00:15<00:00, 63.15it/s]C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#  98%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉    | 979/1000 [00:15<00:00, 63.33it/s]C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#  99%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎  | 986/1000 [00:15<00:00, 63.03it/s]C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
#  99%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋ | 993/1000 [00:15<00:00, 63.33it/s]C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# C:\Users\Administrator\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:6: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:15<00:00, 63.32it/s]

# %%
with open('TMall_user_counts_{}_{}.json'.format('201117', 'V3.2-crosscategorypurchase-past14days'), 'r') as f:
    tmall_user_count_stats = json.load(f)
    
tmall_user_count_stats.keys()
# tmall_user_count_stats['395747']
# Out:
# dict_keys(['152951', '1368', '64713', '161229', '285098', '321029', '222608', '235310', '227090', '182365', '352203', '378993', '127571', '130448', '177503', '204494', '27885', '24786', '386700', '269513', '335442', '378377', '318687', '191131', '314176', '167959', '356016', '318040', '404547', '56065', '383743', '227508', '175992', '186120', '269948', '50500', '44162', '13745', '165026', '320688', '13547', '252795', '313354', '168792', '395144', '119396', '44834', '343302', '108413', '238702', '370321', '416065', '379612', '135575', '296726', '38925', '40619', '354677', '159950', '297609', '141503', '72709', '412039', '380890', '306999', '308141', '233395', '269183', '280447', '43904', '142893', '401850', '51455', '324176', '121943', '348357', '403048', '406233', '396372', '221133', '191428', '410475', '34649', '337355', '379594', '376608', '169881', '319416', '282752', '408820', '177572', '4328', '5862', '146171', '3034', '34448', '247023', '369226', '213963', '410323', '133539', '322006', '39702', '39907', '63780', '199608', '350318', '224110', '78392', '360828', '3069', '204100', '336563', '389109', '211149', '74398', '1759', '196118', '325333', '22791', '176952', '387271', '373406', '356793', '238076', '113359', '43980', '228623', '136975', '227018', '324920', '268686', '142365', '258905', '374076', '235401', '363658', '355895', '227479', '78391', '191538', '163150', '228879', '155604', '190861', '90091', '323509', '270697', '265455', '266479', '262388', '400145', '46074', '95741', '398572', '219531', '385541', '30124', '388071', '422619', '36208', '326845', '391879', '254793', '67161', '313281', '42785', '311734', '423998', '413990', '392246', '407364', '152841', '133254', '388377', '117509', '149387', '282747', '134535', '375006', '226568', '360949', '222913', '389746', '310833', '191036', '237515', '375067', '132218', '359170', '162025', '29970', '25205', '307688', '69115', '362401', '93574', '174470', '235095', '367959', '415068', '411751', '295014', '330658', '49836', '56023', '125960', '273773', '295488', '323880', '179090', '392457', '328829', '207082', '36550', '198903', '75310', '225147', '265840', '203106', '379080', '279783', '61627', '329450', '41139', '16236', '289873', '140656', '414203', '6629', '302748', '204715', '62383', '36387', '62547', '184177', '409104', '66119', '280008', '375739', '362114', '215600', '316719', '405409', '335607', '189945', '178073', '243180', '274902', '208811', '67460', '335237', '232558', '345128', '112748', '117976', '264264', '288846', '240893', '378045', '349810', '79981', '33335', '154549', '185577', '365860', '275151', '411271', '181551', '166971', '277690', '406613', '221100', '417848', '304546', '339853', '39755', '337343', '164321', '304066', '352869', '74394', '197785', '359959', '143266', '376677', '134394', '187060', '405678', '368915', '340502', '109237', '218674', '421759', '243813', '93952', '189045', '320737', '173345', '277553', '226818', '179373', '120355', '222991', '240067', '69896', '292699', '275658', '147384', '134331', '393763', '263217', '326904', '19244', '253402', '119589', '421258', '176748', '157127', '7934', '331888', '81830', '225062', '124471', '341350', '249591', '161475', '366515', '162246', '401163', '385520', '203225', '206725', '411118', '146346', '241116', '183800', '225628', '295605', '350466', '240504', '82345', '308621', '38992', '353892', '207293', '224236', '34705', '86913', '342692', '294146', '283487', '403898', '126019', '29512', '38030', '421869', '129429', '84326', '77099', '326431', '421151', '351638', '30510', '132952', '215153', '388397', '195699', '407778', '106607', '195718', '419477', '351106', '23510', '194704', '328568', '103866', '149559', '87141', '237809', '14712', '124239', '47168', '172748', '114890', '290328', '28690', '12709', '66550', '72708', '14535', '147762', '373847', '152648', '385586', '160033', '161299', '328523', '44130', '280877', '61015', '393349', '19197', '407410', '165566', '200408', '125891', '58289', '2 ...

# %% [markdown]
# ##### Label User States

# %%
tmp_df = pd.DataFrame(tmall_user_count_stats['395747'])

##user_state
# v3_1_cond_list = [
#     (tmp_df['click']+tmp_df['purchase']+tmp_df['add_to_favor_or_cart']+tmp_df['unique_cat']==0),
#     (tmp_df['click']==0)&(tmp_df['purchase']>0),
#     (tmp_df['click']==0)&(tmp_df['add_to_favor_or_cart']>0),
#     (tmp_df['click']>0)&(tmp_df['unique_cat']<3)&(tmp_df['purchase']>0),
#     (tmp_df['click']>0)&(tmp_df['unique_cat']<3)&(tmp_df['add_to_favor_or_cart']>0),
#     (tmp_df['click']>0)&(tmp_df['unique_cat']<3)&(tmp_df['add_to_favor_or_cart']+tmp_df['purchase']==0),
#     (tmp_df['click']>0)&(tmp_df['unique_cat']>=3)&(tmp_df['purchase']>0),
#     (tmp_df['click']>0)&(tmp_df['unique_cat']>=3)&(tmp_df['add_to_favor_or_cart']>0),
#     (tmp_df['click']>0)&(tmp_df['unique_cat']>=3)&(tmp_df['add_to_favor_or_cart']+tmp_df['purchase']==0),
# ]
# v3_1_choice_list = [
#     'no_browse', 'directly_purchase', 'directly_add_to_consider', 'browse_less_cate_to_purchase', 
#     'browse_less_cate_to_add_to_consider', 'browse_less_cate', 'browse_multi_cate_to_purchase', 
#     'browse_multi_cate_to_add_to_consider', 'browse_multi_cate'
# ]


v3_2_cond_list = [
    (tmp_df['click']+tmp_df['purchase']+tmp_df['add_to_favor_or_cart']+tmp_df['unique_cat']==0),
    (tmp_df['click']==0)&(tmp_df['purchase']>0),
    (tmp_df['click']==0)&(tmp_df['add_to_favor_or_cart']>0),
    (tmp_df['click']>0)&(tmp_df['purchase']>0),
    (tmp_df['click']>0)&(tmp_df['add_to_favor_or_cart']>0),
    (tmp_df['click']>0)&(tmp_df['add_to_favor_or_cart']+tmp_df['purchase']==0)
]
v3_2_choice_list = [
    'no_browse', 'directly_purchase', 'directly_add_to_consider', 'browse_to_purchase', 
    'browse_to_add_to_consider', 'browse'
]


# v3_3_cond_list = [
#     (tmp_df['click']+tmp_df['purchase']+tmp_df['add_to_cart']+tmp_df['add_to_favorite']+tmp_df['unique_cat']==0),
#     (tmp_df['click']==0)&(tmp_df['purchase']>0),
#     (tmp_df['click']==0)&(tmp_df['add_to_cart']>0),
#     (tmp_df['click']==0)&(tmp_df['add_to_favorite']>0),
#     (tmp_df['click']>0)&(tmp_df['purchase']>0),
#     (tmp_df['click']>0)&(tmp_df['add_to_cart']>0),
#     (tmp_df['click']>0)&(tmp_df['add_to_favorite']>0),
#     (tmp_df['click']>0)&(tmp_df['add_to_cart']+tmp_df['add_to_favorite']+tmp_df['purchase']==0)
# ]
# v3_3_choice_list = [
#     'no_browse', 'directly_purchase', 'directly_add_to_cart', 'directly_add_to_favorite', 
#     'browse_to_purchase', 'browse_to_add_to_cart', 'browse_to_add_to_favorite', 'browse'
# ]



tmp_df['user_state'] = np.select(condlist=v3_2_cond_list, choicelist=v3_2_choice_list, default='')
tmp_df

# pd.melt(tmp_df, id_vars=['time_stamp'], value_vars=['user_state']).sort_values(['time_stamp','variable']).reset_index().drop(['index','variable'], axis=1)
# Out:
#    time_stamp  click  purchase  add_to_favor_or_cart  unique_cat  \
# 0         504      0         0                     0           0
# 1         505      0         0                     0           0
# 2         506      0         0                     0           0
# 3         507      0         0                     0           0
# 4         508      0         0                     0           0
# 5         509      0         0                     0           0
# 6         510      0         0                     0           0
# 7         511      0         1                     0           1
#
#           user_state
# 0          no_browse
# 1          no_browse
# 2          no_browse
# 3          no_browse
# 4          no_browse
# 5          no_browse
# 6          no_browse
# 7  directly_purchase

# %%
###寫進迴圈應用到所有user

collect = []
for uid in tqdm(tmall_user_count_stats.keys()):

    tmp_df = pd.DataFrame(tmall_user_count_stats[uid])

    ##user_state
#     v3_1_cond_list = [
#         (tmp_df['click']+tmp_df['purchase']+tmp_df['add_to_favor_or_cart']+tmp_df['unique_cat']==0),
#         (tmp_df['click']==0)&(tmp_df['add_to_favor_or_cart']>0),
#         (tmp_df['click']==0)&(tmp_df['purchase']>0),
#         (tmp_df['click']>0)&(tmp_df['unique_cat']<3)&(tmp_df['purchase']>0),
#         (tmp_df['click']>0)&(tmp_df['unique_cat']<3)&(tmp_df['add_to_favor_or_cart']>0),
#         (tmp_df['click']>0)&(tmp_df['unique_cat']<3)&(tmp_df['add_to_favor_or_cart']+tmp_df['purchase']==0),
#         (tmp_df['click']>0)&(tmp_df['unique_cat']>=3)&(tmp_df['purchase']>0),
#         (tmp_df['click']>0)&(tmp_df['unique_cat']>=3)&(tmp_df['add_to_favor_or_cart']>0),
#         (tmp_df['click']>0)&(tmp_df['unique_cat']>=3)&(tmp_df['add_to_favor_or_cart']+tmp_df['purchase']==0),
#     ]
#     v3_1_choice_list = [
#         'no_browse', 'directly_add_to_consider', 'directly_purchase', 'browse_less_cate_to_purchase', 
#         'browse_less_cate_to_add_to_consider', 'browse_less_cate', 'browse_multi_cate_to_purchase', 
#         'browse_multi_cate_to_add_to_consider', 'browse_multi_cate'
#     ]
    
    
    
    v3_2_cond_list = [
        (tmp_df['click']+tmp_df['purchase']+tmp_df['add_to_favor_or_cart']+tmp_df['unique_cat']==0),
        (tmp_df['click']==0)&(tmp_df['purchase']>0),
        (tmp_df['click']==0)&(tmp_df['add_to_favor_or_cart']>0),
        (tmp_df['click']>0)&(tmp_df['purchase']>0),
        (tmp_df['click']>0)&(tmp_df['add_to_favor_or_cart']>0),
        (tmp_df['click']>0)&(tmp_df['add_to_favor_or_cart']+tmp_df['purchase']==0)
    ]
    v3_2_choice_list = [
        'no_browse', 'directly_purchase', 'directly_add_to_consider', 'browse_to_purchase', 
        'browse_to_add_to_consider', 'browse'
    ]


#     v3_3_cond_list = [
#         (tmp_df['click']+tmp_df['purchase']+tmp_df['add_to_cart']+tmp_df['add_to_favorite']+tmp_df['unique_cat']==0),
#         (tmp_df['click']==0)&(tmp_df['purchase']>0),
#         (tmp_df['click']==0)&(tmp_df['add_to_cart']>0),
#         (tmp_df['click']==0)&(tmp_df['add_to_favorite']>0),
#         (tmp_df['click']>0)&(tmp_df['purchase']>0),
#         (tmp_df['click']>0)&(tmp_df['add_to_cart']>0),
#         (tmp_df['click']>0)&(tmp_df['add_to_favorite']>0),
#         (tmp_df['click']>0)&(tmp_df['add_to_cart']+tmp_df['add_to_favorite']+tmp_df['purchase']==0)
#     ]
#     v3_3_choice_list = [
#         'no_browse', 'directly_purchase', 'directly_add_to_cart', 'directly_add_to_favorite', 
#         'browse_to_purchase', 
#         'browse_to_add_to_cart', 'browse_to_add_to_favorite', 'browse'
#     ]


    tmp_df['user_state'] = np.select(condlist=v3_2_cond_list, choicelist=v3_2_choice_list, default='')
    
    ##append to collect list
    uss = tmp_df.user_state.values.tolist()
    uss.insert(0, uid)
    collect.append(uss)

    
##test
collect[98]
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:02<00:00, 344.98it/s]
# ['213963',
#  'no_browse',
#  'no_browse',
#  'no_browse',
#  'no_browse',
#  'no_browse',
#  'no_browse',
#  'directly_add_to_consider',
#  'no_browse',
#  'no_browse',
#  'no_browse',
#  'no_browse',
#  'no_browse',
#  'no_browse',
#  'no_browse',
#  'browse_to_purchase']

# %%
print(produce_date, version)
# Out:
# 201117 V3.2-crosscategorypurchase-past14days

# %%
user_states_col = ['user_id'] + ['day_' + str(x) for x in range(0, pastDays+1)]
user_states_table = pd.DataFrame(collect, columns=user_states_col)
user_states_table.to_csv('TMall_user_state_sequence_table_{}_{}.csv'.format(produce_date, version), index=False)
user_states_table.head(50)
# Out:
#    user_id                     day_0                     day_1  \
# 0   152951                 no_browse                 no_browse
# 1     1368                 no_browse                 no_browse
# 2    64713                 no_browse                 no_browse
# 3   161229                 no_browse                 no_browse
# 4   285098                 no_browse                 no_browse
# 5   321029                 no_browse                 no_browse
# 6   222608                 no_browse                 no_browse
# 7   235310                 no_browse                 no_browse
# 8   227090                 no_browse                 no_browse
# 9   182365                 no_browse                 no_browse
# 10  352203  directly_add_to_consider                 no_browse
# 11  378993  directly_add_to_consider  directly_add_to_consider
# 12  127571                 no_browse                 no_browse
# 13  130448                    browse                    browse
# 14  177503                 no_browse                 no_browse
# 15  204494                 no_browse                 no_browse
# 16   27885                 no_browse                 no_browse
# 17   24786                 no_browse                 no_browse
# 18  386700                 no_browse                 no_browse
# 19  269513                 no_browse                 no_browse
# 20  335442                 no_browse                 no_browse
# 21  378377                 no_browse                    browse
# 22  318687                 no_browse                 no_browse
# 23  191131                 no_browse                 no_browse
# 24  314176                 no_browse                 no_browse
# 25  167959                 no_browse                 no_browse
# 26  356016                 no_browse                 no_browse
# 27  318040                 no_browse                 no_browse
# 28  404547                 no_browse                 no_browse
# 29   56065                 no_browse                 no_browse
# 30  383743                 no_browse                 no_browse
# 31  227508                 no_browse                 no_browse
# 32  175992                 no_browse                 no_browse
# 33  186120                 no_browse                 no_browse
# 34  269948                 no_browse                 no_browse
# 35   50500                 no_browse                 no_browse
# 36   44162                 no_browse                 no_browse
# 37   13745                 no_browse                 no_browse
# 38  165026                 no_browse                 no_browse
# 39  320688                 no_browse                 no_browse
# 40   13547                 no_browse                 no_browse
# 41  252795                 no_browse                 no_browse
# 42  313354                 no_browse                 no_browse
# 43  168792                 no_browse                 no_browse
# 44  395144                 no_browse                 no_browse
# 45  119396                 no_browse                 no_browse
# 46   44834                 no_browse                 no_browse
# 47  343302                 no_browse                 no_browse
# 48  108413                 no_browse                 no_browse
# 49  238702                 no_browse                 no_browse
#
#                         day_2                     day_3  \
# 0                   no_browse                 no_browse
# 1                   no_browse                 no_browse
# 2                   no_browse                 no_browse
# 3                   no_browse                 no_browse
# 4                   no_browse                 no_browse
# 5                   no_browse                 no_browse
# 6                   no_browse                 no_browse
# 7                   no_browse                 no_browse
# 8                   no_browse                 no_browse
# 9                   no_browse                 no_browse
# 10                  no_browse                 no_browse
# 11                  no_browse                 no_browse
# 12                  no_browse                 no_browse
# 13  browse_to_add_to_consider                 no_browse
# 14                  no_browse                 no_browse
# 15                  no_browse                 no_browse
# 16                  no_browse                 no_browse
# 17                  no_browse                 no_browse
# 18                  no_browse                 no_browse
# 19                  no_browse                 no_browse
# 20                  no_browse                 no_browse
# 21                  no_browse                 no_browse
# 22                  no_browse                 no_browse
# 23                  no_browse                 no_browse
# 24                  no_browse                 no_browse
# 25                  no_browse                 no_browse
# 26                  no_browse                 no_browse
# 27                  no_browse                 no_browse
# 28                  no_browse                 no_browse
# 29                  no_browse                 no_browse
# 30                  no_browse                 no_browse
# 31                  no_browse                 no_browse
# 32                  no_browse                 no_browse
# 33                  no_browse                 no_browse
# 34                  no_browse                 no_browse
# 35                  no_browse                 no_browse
# 36                  no_browse                 no_browse
# 37                  no_browse                 no_browse
# 38                  no_browse                 no_browse
# 39                  no_browse  directly_add_to_consider
# 40                  no_browse                 no_browse
# 41                  no_browse                 no_browse
# 42                  no_browse                 no_browse
# 43                  no_browse                 no_browse
# 44                  no_browse                 no_browse
# 45                  no_browse                 no_browse
# 46                  no_browse                 no_browse
# 47                  no_browse                 no_browse
# 48                  no_browse                 no_browse
# 49                  no_browse                 no_browse
#
#                        day_4                     day_5  \
# 0                  no_browse                 no_browse
# 1                  no_browse                 no_browse
# 2                  no_browse                 no_browse
# 3                  no_browse                 no_browse
# 4                  no_browse                 no_browse
# 5                  no_browse                 no_browse
# 6                  no_browse                 no_browse
# 7                  no_browse                 no_browse
# 8                  no_browse                 no_browse
# 9                  no_browse                 no_browse
# 10                 no_browse                 no_browse
# 11                 no_browse                 no_browse
# 12                 no_browse                 no_browse
# 13                 no_browse                 no_browse
# 14                 no_browse                 no_browse
# 15                 no_browse                 no_browse
# 16                 no_browse                 no_browse
# 17                 no_browse                 no_browse
# 18                 no_browse                 no_browse
# 19                 no_browse                 no_browse
# 20                 no_browse                 no_browse
# 21                 no_browse                 no_browse
# 22                 no_browse                 no_browse
# 23                 no_browse                 no_browse
# 24                 no_browse                 no_browse
# 25                 no_browse                 no_browse
# 26                 no_browse                 no_browse
# 27                 no_browse                 no_browse
# 28                 no_browse                 no_browse
# 29                 no_browse                 no_browse
# 30                 no_browse                 no_browse
# 31                 no_browse                 no_browse
# 32                 no_browse                 no_browse
# 33                 no_browse                 no_browse
# 34                 no_browse                 no_browse
# 35                 no_browse                 no_browse
# 36                 no_browse                 no_browse
# 37                 no_browse                 no_browse
# 38                 no_browse                 no_browse
# 39  directly_add_to_consider  directly_add_to_consider
# 40                 no_browse                 no_browse
# 41                 no_browse                 no_browse
# 42                 no_browse                 no_browse
# 43                 no_browse                 no_browse
# 44                 no_browse                 no_browse
# 45                 no_browse                 no_browse
# 46                 no_browse                 no_browse
# 47                 no_browse                 no_browse
# 48                 no_browse                 no_browse
# 49                 no_browse                 no_browse
#
#                        day_6                      day_7  \
# 0                  no_browse                  no_browse
# 1   directly_add_to_consider                  no_browse
# 2                  no_browse                  no_browse
# 3                  no_browse                  no_browse
# 4                  no_browse                  no_browse
# 5                  no_browse                  no_browse
# 6                  no_browse                  no_browse
# 7                  no_browse                  no_browse
# 8                  no_browse                  no_browse
# 9                  no_browse                  no_browse
# 10                 no_browse                  no_browse
# 11                 no_browse                  no_browse
# 12                 no_browse                  no_browse
# 13                 no_browse                  no_browse
# 14                 no_browse                  no_browse
# 15                 no_browse                  no_browse
# 16                 no_browse                  no_browse
# 17                 no_browse                  no_browse
# 18                 no_browse                  no_browse
# 19                 no_browse                  no_browse
# 20                 no_browse                  no_browse
# 21                 no_browse                  no_browse
# 22                 no_browse                  no_browse
# 23                 no_browse  browse_to_add_to_consider
# 24                 no_browse   directly_add_to_consider
# 25                 no_browse                  no_browse
# 26                 no_browse                  no_browse
# 27                 no_browse                  no_browse
# 28                 no_browse                  no_browse
# 29                 no_browse                  no_browse
# 30                 no_browse                  no_browse
# 31                 no_browse                  no_browse
# 32                 no_browse                  no_browse
# 33                 no_browse                     browse
# 34                 no_browse                  no_browse
# 35                 no_browse                  no_browse
# 36                 no_browse                  no_browse
# 37                 no_browse                  no_browse
# 38                 no_browse                  no_browse
# 39  directly_add_to_consider   directly_add_to_consider
# 40                 no_browse                  no_browse
# 41                 no_browse                  no_browse
# 42                 no_browse                  no_browse
# 43                 no_browse                  no_browse
# 44                 no_browse                  no_browse
# 45                 no_browse                  no_browse
# 46                 no_browse                  no_browse
# 47                 no_browse                  no_browse
# 48                 no_browse                  no_browse
# 49                 no_browse                  no_browse
#
#                         day_8                     day_9     day_10  \
# 0                   no_browse                 no_browse  no_browse
# 1                   no_browse                 no_browse  no_browse
# 2                   no_browse                 no_browse  no_browse
# 3                   no_browse                 no_browse  no_browse
# 4                   no_browse                 no_browse  no_browse
# 5                   no_browse                 no_browse  no_browse
# 6                   no_browse                 no_browse  no_browse
# 7                   no_browse                 no_browse  no_browse
# 8                   no_browse                 no_browse  no_browse
# 9                   no_browse                 no_browse  no_browse
# 10                  no_browse                 no_browse     browse
# 11                  no_browse  directly_add_to_consider  no_browse
# 12                  no_browse                 no_browse  no_browse
# 13                     browse                 no_browse     browse
# 14                  no_browse                 no_browse  no_browse
# 15                  no_browse                 no_browse  no_browse
# 16                  no_browse                 no_browse  no_browse
# 17                  no_browse                 no_browse  no_browse
# 18                  no_browse                 no_browse  no_browse
# 19                  no_browse                 no_browse  no_browse
# 20                  no_browse                 no_browse  no_browse
# 21                     browse                 no_browse  no_browse
# 22                  no_browse                 no_browse  no_browse
# 23  browse_to_add_to_consider                 no_browse  no_browse
# 24   directly_add_to_consider                 no_browse  no_browse
# 25                  no_browse                 no_browse  no_browse
# 26                  no_browse                 no_browse  no_browse
# 27                  no_browse                 no_browse  no_browse
# 28                  no_browse                 no_browse  no_browse
# 29                  no_browse                 no_browse  no_browse
# 30                  no_browse                 no_browse  no_browse
# 31                  no_browse                 no_browse  no_browse
# 32                  no_browse                 no_browse  no_browse
# 33                  no_browse                 no_browse  no_browse
# 34                  no_browse                 no_browse  no_browse
# 35                  no_browse                 no_browse  no_browse
# 36                  no_browse                 no_browse  no_browse
# 37                  no_browse                 no_browse  no_browse
# 38                  no_browse                 no_browse  no_browse
# 39                  no_browse  directly_add_to_consider  no_browse
# 40                  no_browse                 no_browse  no_browse
# 41                  no_browse                 no_browse  no_browse
# 42                  no_browse                 no_browse  no_browse
# 43                  no_browse                 no_browse  no_browse
# 44                  no_browse  directly_add_to_consider  no_browse
# 45                  no_browse                 no_browse  no_browse
# 46                  no_browse                 no_browse  no_browse
# 47                  no_browse                 no_browse  no_browse
# 48                  no_browse                 no_browse  no_browse
# 49                  no_browse                 no_browse  no_browse
#
#                        day_11                     day_12  \
# 0                   no_browse                  no_browse
# 1                   no_browse                  no_browse
# 2                   no_browse                  no_browse
# 3                   no_browse                  no_browse
# 4                   no_browse                  no_browse
# 5                   no_browse                  no_browse
# 6                   no_browse                  no_browse
# 7                   no_browse                  no_browse
# 8                   no_browse                  no_browse
# 9                   no_browse                  no_browse
# 10                  no_browse                     browse
# 11                  no_browse                  no_browse
# 12                  no_browse                  no_browse
# 13  browse_to_add_to_consider                  no_browse
# 14                  no_browse                  no_browse
# 15                  no_browse                  no_browse
# 16                  no_browse   directly_add_to_consider
# 17                  no_browse                  no_browse
# 18                  no_browse                  no_browse
# 19                  no_browse                  no_browse
# 20                  no_browse                  no_browse
# 21                  no_browse                  no_browse
# 22                  no_browse                  no_browse
# 23                  no_browse                  no_browse
# 24                  no_browse   directly_add_to_consider
# 25                  no_browse                  no_browse
# 26                  no_browse                  no_browse
# 27                  no_browse                  no_browse
# 28                  no_browse                  no_browse
# 29                  no_browse                  no_browse
# 30                  no_browse                  no_browse
# 31                  no_browse                  no_browse
# 32                  no_browse                  no_browse
# 33                  no_browse                  no_browse
# 34                  no_browse                  no_browse
# 35                  no_browse                  no_browse
# 36                  no_browse                  no_browse
# 37                  no_browse                  no_browse
# 38                  no_browse                  no_browse
# 39                  no_browse  browse_to_add_to_consider
# 40                  no_browse   directly_add_to_consider
# 41                  no_browse                  no_browse
# 42                  no_browse                  no_browse
# 43                  no_browse                  no_browse
# 44                  no_browse                  no_browse
# 45                  no_browse                  no_browse
# 46                  no_browse                  no_browse
# 47                  no_browse                  no_browse
# 48                  no_browse                  no_browse
# 49                  no_browse                  no_browse
#
#                        day_13              day_14
# 0                   no_browse   directly_purchase
# 1                   no_browse   directly_purchase
# 2                   no_browse   directly_purchase
# 3                   no_browse   directly_purchase
# 4                   no_browse   directly_purchase
# 5                   no_browse   directly_purchase
# 6                   no_browse   directly_purchase
# 7                   no_browse   directly_purchase
# 8                   no_browse  browse_to_purchase
# 9                   no_browse   directly_purchase
# 10                  no_browse  browse_to_purchase
# 11                  no_browse   directly_purchase
# 12                  no_browse   directly_purchase
# 13                     browse  browse_to_purchase
# 14                  no_browse   directly_purchase
# 15                  no_browse   directly_purchase
# 16   directly_add_to_consider   directly_purchase
# 17                  no_browse   directly_purchase
# 18                  no_browse   directly_purchase
# 19                  no_browse   directly_purchase
# 20                  no_browse   directly_purchase
# 21                  no_browse  browse_to_purchase
# 22                  no_browse   directly_purchase
# 23  browse_to_add_to_consider  browse_to_purchase
# 24   directly_add_to_consider   directly_purchase
# 25   directly_add_to_consider   directly_purchase
# 26                  no_browse   directly_purchase
# 27                  no_browse   directly_purchase
# 28                  no_browse   directly_purchase
# 29                  no_browse   directly_purchase
# 30                  no_browse   directly_purchase
# 31                  no_browse   directly_purchase
# 32                     browse  browse_to_purchase
# 33                     browse  browse_to_purchase
# 34                  no_browse   directly_purchase
# 35                  no_browse   directly_purchase
# 36   directly_add_to_consider   directly_purchase
# 37                  no_browse   directly_purchase
# 38                  no_browse   directly_purchase
# 39                  no_browse  browse_to_purchase
# 40   directly_add_to_consider   directly_purchase
# 41                  no_browse   directly_purchase
# 42                  no_browse   directly_purchase
# 43                  no_browse   directly_purchase
# 44                  no_browse   directly_purchase
# 45                  no_browse   directly_purchase
# 46                  no_browse   directly_purchase
# 47                  no_browse   directly_purchase
# 48                  no_browse   directly_purchase
# 49                  no_browse   directly_purchase

# %%
collect_all = list()
for l in collect:
    for item in l[1:]:
        collect_all.append(item)
    
pd.DataFrame(collect_all, columns=['items']).groupby(['items']).size().reset_index().rename(columns={0: 'count'})
# Out:
#                        items  count
# 0                     browse    486
# 1  browse_to_add_to_consider    131
# 2         browse_to_purchase    688
# 3   directly_add_to_consider    116
# 4          directly_purchase    312
# 5                  no_browse  13267
